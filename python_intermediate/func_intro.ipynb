# %%
def say_hello():
    print("Hello!")

# %%
say_hello()
# Out:
# Hello!

# %%
def say_hello(name):
    print(f"Hello! {name}")

# %%
say_hello("Mehedi")
# Out:
# Hello! Mehedi

# %%
say_hello("Mimi")
# Out:
# Hello! Mimi
