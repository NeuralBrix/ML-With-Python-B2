# %%
# if, elif, else

# %%
age = 10

# %%
if age>18:
    print("You can vote")
else:
    print("You can not vote")
# Out:
# You can not vote

# %%
#if elif else chain

# %%
age = 18

if age<4:
    price=0
elif age<18:
    price=25
else:
    price=40

print(f"You have to give {price}")
# Out:
# You have to give 40

# %%
# Comparison Operator

car="bmw"
print(car=='bmw')
print(car=='audi')
print(car!="audi")
# Out:
# True
# False
# True

# %%
#Numerical comparisons

age = 18

print(age==18)
print(age!=18)
print(age<21)
print(age<=18) 
print(age>16)
print(age>=18)
# Out:
# True
# False
# True
# True
# True
# True

# %%
#Logical Operators or, and
#and gun er moto kaj kore
#or jog er moto kaj kore

age_0 = 22
age_1 = 18

#and operator
print(age_0>=21 and age_1<=21)
# Out:
# True

# %%
print(age_0>=21 and age_1>=21)
# Out:
# False

# %%
print(age_0>=21 or age_1>=21)
# Out:
# True

# %%
print(age_0<=21 or age_1>=21)
# Out:
# False
