# %%
#immutable
#int, float, str, tuple, bool, frozenset
#mutalble
#list, dict, set

# %%
#immutable
x = 12
y = 12.12
name = "Mehedi"
age_number = (12,1,2,3,4,4)
is_student = True

# %%
#mutable
age_number = [12,1,2,3,4,4]
name_age = {"mehedi": 30, "Karim":40}
age_set = {12,1,2,3,4}

# %%
frozen_age_number = frozenset(age_number)
frozen_age_number
# Out:
# frozenset({1, 2, 3, 4, 12})

# %%
#for var in sequence:
    #  code block ba loop body

# %%
fruits = ["apple", "banana", "cherry", "date"]

# %%
for fruit_name in fruits:
    print("fruit name is :", fruit_name)
# Out:
# fruit name is : apple
# fruit name is : banana
# fruit name is : cherry
# fruit name is : date

# %%
## range()

#range(start, stop, step) #excluding stop

# %%
#range(start, stop)
for vlaue in range(1,5):
    print(vlaue)
# Out:
# 1
# 2
# 3
# 4

# %%
list(range(0,15,3))
# Out:
# [0, 3, 6, 9, 12]

# %%
squares = list()
for num in range(1,11):
    squares.append(num**2)

# %%
squares
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#list comprehension 
#[expression for item in iterable]
[item**2 for item in range(1,11)]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
#basic syntax
# while condition:

# %%
current_num = 1
while current_num <= 5: 
    print(current_num)
    current_num = current_num+1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
fruit_name = ['apple', 'banana', 'mango', 'orange']

# %%
for index, f_name in enumerate(fruit_name):
    print(f"index : {index+1} fruit name: {f_name}")
# Out:
# index : 1 fruit name: apple
# index : 2 fruit name: banana
# index : 3 fruit name: mango
# index : 4 fruit name: orange
