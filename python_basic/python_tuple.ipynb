# %%
# ()

# %%
dimension = (200,50,20,40,10)

# %%
print(dimension[0])
# Out:
# 200

# %%
for i in dimension:
    print(i)
# Out:
# 200
# 50
# 20
# 40
# 10

# %%
# op with tuple

t1 = (10,20,30)
t2 = (40,50,60)

t3 = t1 + t2
t3
# Out:
# (10, 20, 30, 40, 50, 60)

# %%
t3*3
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
# slicing
t4 = (10,20,30,40,50,60,70,80,90)
t4[2:6:2]
# Out:
# (30, 50)

# %%
20 in t4
# Out:
# True

# %%
1 not in t4
# Out:
# True

# %%
100 in t4
# Out:
# False

# %%
a = 10,20,30
a
# Out:
# (10, 20, 30)

# %%
type(a)
# Out:
# tuple

# %%
q,w,e = a

# %%
print(q)
print(w)
print(e)
# Out:
# 10
# 20
# 30
