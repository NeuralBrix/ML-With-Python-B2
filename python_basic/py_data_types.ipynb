# %% [markdown]
# ## Variables and Data types

# %%
#integer 
age = 30 
print("My age is ", age)
# Out:
# My age is  30

# %%
#float
pi = 3.1416
print(pi)
# Out:
# 3.1416

# %%
#str
my_name = "Mehedi"
print("My name is: " +my_name)
# Out:
# My name is: Mehedi

# %%
#boolean

is_student = True 
not_student = False 

print(is_student) 
print(not_student) 
type(not_student)
# Out:
# True
# False
# bool

# %%
age = 30 
print("My age is " + str(age))
# Out:
# My age is 30

# %%
type(age)
# Out:
# int

# %%
age = "30"
print(type(age)) 
age = int(age) 
print(type(age))
# Out:
# <class 'str'>
# <class 'int'>

# %%
name = input("Enter your name: ")
type(name)
# Out:
# str

# %%
print(name)
# Out:
# Mehedi

# %%
age = 30 #My age is 30

print(f"My name is {name} and my age is {age}")
# Out:
# My name is Mehedi and my age is 30
