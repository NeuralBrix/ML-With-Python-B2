# %%
params = {"learning_rate":0.01, "batch_size":32, 'Optimizer':"adam", "Epochs":50}

# %%
params
# Out:
# {'learning_rate': 0.01, 'batch_size': 32, 'Optimizer': 'adam', 'Epochs': 50}

# %%
params["learning_rate"]
# Out:
# 0.01

# %%
params["Optimizer"]
# Out:
# 'adam'

# %%
## add or update a value
params["Epochs"]=30

# %%
params
# Out:
# {'learning_rate': 0.01, 'batch_size': 32, 'Optimizer': 'adam', 'Epochs': 30}

# %%
params["model_name"]="KNN"

# %%
params
# Out:
# {'learning_rate': 0.01,
#  'batch_size': 32,
#  'Optimizer': 'adam',
#  'Epochs': 30,
#  'model_name': 'KNN'}

# %%
del params['model_name']

# %%
params
# Out:
# {'learning_rate': 0.01, 'batch_size': 32, 'Optimizer': 'adam', 'Epochs': 30}

# %% [markdown]
# # common method

# %%
params = {'learning_rate': 0.01, 'batch_size': 32, 'Optimizer': 'adam', 'Epochs': 30}

# %%
## len method will count keys in the dictionary
len(params)
# Out:
# 4

# %%
params['learning_rate']
# Out:
# 0.01

# %%
"learning_rate" in params
# Out:
# True

# %%
"dropout" in params
# Out:
# False

# %%
# get safe method
test = params.get("batch_size") 
test
# Out:
# 32

# %%
test_2 = params.get("lr") 
test_2

# %%
test_2

# %%
params.pop("batch_size")
# Out:
# 32

# %%
params
# Out:
# {'learning_rate': 0.01, 'Optimizer': 'adam', 'Epochs': 30}

# %%
key_, vlaue_ = params.popitem()

# %%
key_
# Out:
# 'Epochs'

# %%
vlaue_
# Out:
# 30

# %%
params = {"learning_rate":0.01, "batch_size":32, 'Optimizer':"adam", "Epochs":50}

# %%
params.update({"Epochs":100, "dropout":0.5})

# %%
params
# Out:
# {'learning_rate': 0.01,
#  'batch_size': 32,
#  'Optimizer': 'adam',
#  'Epochs': 100,
#  'dropout': 0.5}

# %%
params.keys()
# Out:
# dict_keys(['learning_rate', 'batch_size', 'Optimizer', 'Epochs', 'dropout'])

# %%
params.values()
# Out:
# dict_values([0.01, 32, 'adam', 100, 0.5])

# %%
params.items()
# Out:
# dict_items([('learning_rate', 0.01), ('batch_size', 32), ('Optimizer', 'adam'), ('Epochs', 100), ('dropout', 0.5)])

# %%
params.clear()

# %%
params
# Out:
# {}

# %%
names = ['Alice', 'Bob', 'Charlie']
ages = [25, 30, 35]
person_dict = dict(zip(names, ages))

# %%
person_dict
# Out:
# {'Alice': 25, 'Bob': 30, 'Charlie': 35}

# %%
names = ['Alice', 'Bob', 'Charlie']
ages = [25, 30, 35]
locations = ['New York', 'Los Angeles', 'Chicago']
z = zip(names, ages, locations)

# %%
for name, age, place in z:
    print(f"Name: {name}, Age: {age}, Location: {place}")
# Out:
# Name: Alice, Age: 25, Location: New York
# Name: Bob, Age: 30, Location: Los Angeles
# Name: Charlie, Age: 35, Location: Chicago
