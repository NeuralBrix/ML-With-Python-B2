# %%
a = 10
b = 10

# %%
hex(id(a))
# Out:
# '0x1a09d7c0210'

# %%
hex(id(b))
# Out:
# '0x1a09d7c0210'

# %%
t1 = "Mehedi"
t2 = "Mehedi"

# %%
hex(id(t1))
# Out:
# '0x1a0a1207a70'

# %%
hex(id(t2))
# Out:
# '0x1a0a1207a70'

# %%
a = -6
b = -6

# %%
hex(id(a)) , hex(id(b))
# Out:
# ('0x1a0a24da790', '0x1a0a24d9690')

# %%
-5 to 256
