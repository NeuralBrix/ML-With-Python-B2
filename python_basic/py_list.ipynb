# %%
fruits =["apple", "banana", 'Mango', 'lychee']

# %%
fruits
# Out:
# ['apple', 'banana', 'Mango', 'lychee']

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[3]
# Out:
# 'lychee'

# %%
# negative indexing
fruits[-1]
# Out:
# 'lychee'

# %%
fruits[-4]
# Out:
# 'apple'

# %%
# Modifying Elements

# %%
fruits =["apple", "banana", 'Mango', 'lychee']

# %%
fruits
# Out:
# ['apple', 'banana', 'Mango', 'lychee']

# %%
fruits[0] = "Komola"

# %%
fruits
# Out:
# ['Komola', 'banana', 'Mango', 'lychee']

# %%
fruits.append("Apple")

# %%
fruits
# Out:
# ['Komola', 'banana', 'Mango', 'lychee', 'Apple']

# %%
fruits.insert(1, 'Apple')

# %%
fruits
# Out:
# ['Komola', 'Apple', 'banana', 'Mango', 'lychee', 'Apple']

# %%
# Removing Items

# %%
del fruits[-1]

# %%
fruits
# Out:
# ['Komola', 'Apple', 'banana', 'Mango', 'lychee']

# %%
fruits.pop()
# Out:
# 'lychee'

# %%
fruits
# Out:
# ['Komola', 'Apple', 'banana', 'Mango']

# %%
last_fruit = fruits.pop()

# %%
last_fruit
# Out:
# 'Mango'

# %%
fruits
# Out:
# ['Komola', 'Apple', 'banana']

# %%
fruit = fruits.pop(1)

# %%
fruit
# Out:
# 'Apple'

# %%
fruits
# Out:
# ['Komola', 'banana']

# %%
fruits.remove("banana")

# %%
fruits
# Out:
# ['Komola']

# %%
fruits.remove("Komola")

# %%
fruits
# Out:
# []
